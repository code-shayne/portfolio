# %% [markdown]
# # 2/3 Notes - Day 1
# ## gerbil

# %% [markdown]
# ### zen
# ![image.png](attachment:image.png)

# %% [markdown]
# ### yatta
# ![image.png](attachment:image.png)

# %%
print('hello gerbils')
# Out:
# hello gerbils

# %%
x = 'gerbil'
x
# Out:
# 'gerbil'

# %%
print('hello '+x)
# Out:
# hello gerbil

# %%
y=2.4
print(y)
# Out:
# 2.4

# %%
type(y)
# Out:
# float

# %%
last_name = "dorick"
print (x +" "+ last_name)
# Out:
# gerbil dorick

# %%
x
# Out:
# 'gerbil'

# %%
gerbil_cute = True
# must be capital

# %%
print("zen and yatta "+last_name)
# Out:
# zen and yatta dorick

# %%
name = input('name a gerbil.')
# Out:
# name a gerbil.jeff star

# %%
name
# Out:
# 'jeff star'

# %%
num_yaks = int(input('how many yaks does jeff have?'))
#int() makes it an int value instead of string
# Out:
# how many yaks does jeff have?1000000000000000

# %%
num_yaks
# Out:
# 1000000000000000

# %%
type(num_yaks)
# Out:
# int
